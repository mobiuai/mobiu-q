# %%
# @title 📦 Installation
print("Installing core packages...")
# !pip install gymnasium torch numpy scipy --quiet

print("Installing SWIG (System dependency)...")
# !apt-get install -y swig > /dev/null 2>&1

print("Installing RL libraries (Box2D for LunarLander)...")
# !pip install gymnasium[box2d] stable-baselines3 shimmy > /dev/null 2>&1

print("✅ Installation Complete!")
# Out:
# Installing core packages...
# Installing SWIG (System dependency)...
# Installing RL libraries (Box2D for LunarLander)...
# ✅ Installation Complete!

# %%
# !python test_rl_local.py
# Out:
# ...
# 🔬 MOBIU-Q RL LOCAL TEST
# ...
# Environment: LunarLander-v3
# Episodes: 1000 | Seeds: 30
# ...
#
# Seed 1/30
#   Adam: -34.4 | Mobiu: 9.1
#
# Seed 2/30
#   Adam: -37.6 | Mobiu: 31.2
#
# Seed 3/30
#   Adam: -15.5 | Mobiu: 9.6
#
# Seed 4/30
#   Adam: -10.8 | Mobiu: 10.6
#
# Seed 5/30
#   Adam: -51.2 | Mobiu: 6.7
#
# Seed 6/30
#   Adam: -63.3 | Mobiu: 12.8
#
# Seed 7/30
#   Adam: -34.4 | Mobiu: 0.1
#
# Seed 8/30
#   Adam: -17.2 | Mobiu: 55.3
#
# Seed 9/30
#   Adam: -19.2 | Mobiu: -4.8
#
# Seed 10/30
#   Adam: -32.4 | Mobiu: 41.5
#
# Seed 11/30
#   Adam: -7.1 | Mobiu: -0.7
#
# Seed 12/30
#   Adam: -54.0 | Mobiu: 7.6
#
# Seed 13/30
#   Adam: -45.5 | Mobiu: -31.6
#
# Seed 14/30
#   Adam: -29.6 | Mobiu: 11.7
#
# Seed 15/30
#   Adam: -54.6 | Mobiu: 26.1
#
# Seed 16/30
#   Adam: -20.0 | Mobiu: -46.0
#
# Seed 17/30
#   Adam: -39.6 | Mobiu: 1.8
#
# Seed 18/30
#   Adam: -43.6 | Mobiu: 35.3
#
# Seed 19/30
#   Adam: -21.2 | Mobiu: 7.1
#
# Seed 20/30
#   Adam: -75.3 | Mobiu: -12.8
#
# Seed 21/30
# ...

# %%
# !pip install gymnasium[mujoco]
# !python test_mujoco_multi_env.py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 61.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 18.0 MB/s eta 0:00:00
# ...
# 🤖 MOBIU-Q MUJOCO MULTI-ENVIRONMENT BENCHMARK
# ...
# ✓ InvertedPendulum-v5: obs=4, act=1
# ✓ Hopper-v5: obs=11, act=3
# ✓ HalfCheetah-v5: obs=17, act=6
#
# Episodes: 300 | Seeds: 10
# ...
#
# ...
# 🎮 ENVIRONMENT: InvertedPendulum-v5
# ...
#
#   Seed 1/10 [Adam.....] [Mobiu.....] | Adam: 20.1 | Mobiu: 64.0 | ✓
#
#   Seed 2/10 [Adam.....] [Mobiu.....] | Adam: 23.2 | Mobiu: 57.2 | ✓
#
#   Seed 3/10 [Adam.....] [Mobiu.....] | Adam: 16.6 | Mobiu: 25.6 | ✓
#
#   Seed 4/10 [Adam.....] [Mobiu.....] | Adam: 14.7 | Mobiu: 33.9 | ✓
#
#   Seed 5/10 [Adam.....] [Mobiu.....] | Adam: 29.4 | Mobiu: 36.2 | ✓
#
#   Seed 6/10 [Adam.....] [Mobiu.....] | Adam: 23.3 | Mobiu: 40.1 | ✓
#
#   Seed 7/10 [Adam.....] [Mobiu.....] | Adam: 20.6 | Mobiu: 48.2 | ✓
#
# ...
